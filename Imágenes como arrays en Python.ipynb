# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import  Image

# %%
pwd
# Out:
# '/home/infinity/Documentos/CURSOS/CURSOS UDEMY/Curso de Python y OpenCV para computer vision'

# %%
imagen = Image.open('cat_or_dog_4.jpg')
imagen
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x412 at 0x7FE4B055BAD0>

# %%
type(imagen)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
imagen.size
# Out:
# (500, 412)

# %%
array_imagen = np.asarray(imagen)
array_imagen
# Out:
# array([[[138, 127, 105],
#         [131, 120, 100],
#         [112,  96,  81],
#         ...,
#         [ 35,  27,  38],
#         [ 35,  27,  38],
#         [ 35,  27,  38]],
#
#        [[140, 129, 107],
#         [132, 121, 101],
#         [112,  96,  81],
#         ...,
#         [ 34,  26,  37],
#         [ 34,  26,  37],
#         [ 34,  26,  37]],
#
#        [[143, 133, 108],
#         [134, 121, 102],
#         [112,  96,  81],
#         ...,
#         [ 36,  28,  39],
#         [ 36,  28,  39],
#         [ 36,  28,  39]],
#
#        ...,
#
#        [[255, 149, 204],
#         [254, 146, 198],
#         [255, 144, 195],
#         ...,
#         [252, 203, 235],
#         [255, 216, 246],
#         [255, 227, 254]],
#
#        [[251, 139, 195],
#         [246, 134, 190],
#         [245, 134, 187],
#         ...,
#         [253, 206, 238],
#         [255, 221, 250],
#         [255, 231, 255]],
#
#        [[237, 124, 180],
#         [232, 119, 175],
#         [230, 117, 171],
# ...

# %%
plt.imshow(array_imagen)

# %%
print(imagen.size)
array_imagen.shape# se inveierte las dimension
# Out:
# (500, 412)
# (412, 500, 3)

# %%
array_imagen[:,:,0]# dimension Cero para el color Rojo
# Out:
# array([[138, 131, 112, ...,  35,  35,  35],
#        [140, 132, 112, ...,  34,  34,  34],
#        [143, 134, 112, ...,  36,  36,  36],
#        ...,
#        [255, 254, 255, ..., 252, 255, 255],
#        [251, 246, 245, ..., 253, 255, 255],
#        [237, 232, 230, ..., 253, 255, 255]], dtype=uint8)

# %%
array_imagen[:,:,1]# dimension 1 para el color VERDE
# Out:
# array([[127, 120,  96, ...,  27,  27,  27],
#        [129, 121,  96, ...,  26,  26,  26],
#        [133, 121,  96, ...,  28,  28,  28],
#        ...,
#        [149, 146, 144, ..., 203, 216, 227],
#        [139, 134, 134, ..., 206, 221, 231],
#        [124, 119, 117, ..., 208, 222, 233]], dtype=uint8)

# %%
array_imagen[:,:,2]# dimension 2 para el color AZUL
# Out:
# array([[105, 100,  81, ...,  38,  38,  38],
#        [107, 101,  81, ...,  37,  37,  37],
#        [108, 102,  81, ...,  39,  39,  39],
#        ...,
#        [204, 198, 195, ..., 235, 246, 254],
#        [195, 190, 187, ..., 238, 250, 255],
#        [180, 175, 171, ..., 239, 251, 255]], dtype=uint8)

# %%
array_imagen
# Out:
# array([[[138, 127, 105],
#         [131, 120, 100],
#         [112,  96,  81],
#         ...,
#         [ 35,  27,  38],
#         [ 35,  27,  38],
#         [ 35,  27,  38]],
#
#        [[140, 129, 107],
#         [132, 121, 101],
#         [112,  96,  81],
#         ...,
#         [ 34,  26,  37],
#         [ 34,  26,  37],
#         [ 34,  26,  37]],
#
#        [[143, 133, 108],
#         [134, 121, 102],
#         [112,  96,  81],
#         ...,
#         [ 36,  28,  39],
#         [ 36,  28,  39],
#         [ 36,  28,  39]],
#
#        ...,
#
#        [[255, 149, 204],
#         [254, 146, 198],
#         [255, 144, 195],
#         ...,
#         [252, 203, 235],
#         [255, 216, 246],
#         [255, 227, 254]],
#
#        [[251, 139, 195],
#         [246, 134, 190],
#         [245, 134, 187],
#         ...,
#         [253, 206, 238],
#         [255, 221, 250],
#         [255, 231, 255]],
#
#        [[237, 124, 180],
#         [232, 119, 175],
#         [230, 117, 171],
# ...

# %% [markdown]
# # INSTALACION DE OPENCV

# %%
# conda install opencv=3.4.2

# %%
import cv2

# %%
cv2.__version__
# Out:
# '4.2.0'

# %%
imagen1 = cv2.imread('cat_or_dog_4.jpg')
imagen1
# Out:
# array([[[105, 127, 138],
#         [100, 120, 131],
#         [ 83,  96, 112],
#         ...,
#         [ 38,  27,  35],
#         [ 38,  27,  35],
#         [ 38,  27,  35]],
#
#        [[107, 129, 140],
#         [101, 120, 133],
#         [ 83,  96, 112],
#         ...,
#         [ 37,  26,  34],
#         [ 37,  26,  34],
#         [ 37,  26,  34]],
#
#        [[110, 132, 144],
#         [102, 121, 134],
#         [ 81,  96, 112],
#         ...,
#         [ 39,  28,  36],
#         [ 39,  28,  36],
#         [ 39,  28,  36]],
#
#        ...,
#
#        [[202, 150, 255],
#         [198, 146, 254],
#         [195, 144, 255],
#         ...,
#         [235, 203, 250],
#         [246, 216, 255],
#         [254, 226, 255]],
#
#        [[195, 139, 251],
#         [188, 135, 246],
#         [185, 133, 246],
#         ...,
#         [238, 207, 252],
#         [250, 221, 255],
#         [255, 230, 255]],
#
#        [[180, 124, 236],
#         [173, 120, 231],
#         [171, 117, 230],
# ...

# %%
type(imagen1)
# Out:
# numpy.ndarray

# %%
imagen1.shape
# Out:
# (412, 500, 3)

# %%
plt.imshow(imagen1)

# %% [markdown]
# ## *OpenCV --> BGR (blue, green, red)*
#
# ## *Matplotlib --> RGB (red, green, blue)*

# %% [markdown]
# # cambar de BGR a  RGB la imagen

# %%
imagen2 = cv2.cvtColor(imagen1, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imagen2)

# %%
# LEER LA IMAGEN EN ESCALA DE GRISES-
imagen_blanco_negro = cv2.imread('cat_or_dog_4.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(imagen_blanco_negro, cmap='gray')
